# %%
import pandas as pd
import numpy as np

# %%
players = pd.read_csv('boxscores2019.csv')

# %%
players = players[~(pd.isnull(players.player) | (players.player=="TE"))]

# %%
players
# Out:
#               id team                        player MIN     FG  3PT    FT  \
# 0      401160630  bos              J. TatumJ. Tatum  37   8-22  4-8   1-3
# 1      401160630  bos          G. HaywardG. Hayward  35   8-15  0-0  9-11
# 2      401160630  bos            E. KanterE. Kanter  25    5-8  0-1   2-7
# 3      401160630  bos            K. WalkerK. Walker  34   4-18  1-6   3-4
# 4      401160630  bos              J. BrownJ. Brown  21    3-6  1-2   1-3
# ...          ...  ...                           ...  ..    ...  ...   ...
# 26626  401161311  cha         M. WilliamsM. William  28   5-12  4-7   4-4
# 26627  401161311  cha          M. BridgesM. Bridges  19    1-5  1-2   0-0
# 26628  401161311  cha          B. BiyomboB. Biyombo   8    0-3  0-0   0-0
# 26629  401161311  cha  W. HernangomezW. Hernangomez   8    0-1  0-0   3-4
# 26630  401161311  cha                M. MonkM. Monk  34  10-17  3-7   8-9
#
#       OREB DREB REB AST STL BLK TO PF  +/- PTS position
# ...

# %%
def find_duplicate(x):
    for i in range(len(x)):
        if x[:i] == x[i:]:
            return x[:i]
        if x[:i-1] == x[i:]:
            return x[:i]
    else:
        return np.nan

# %%
players["Name"] = players.player.apply(find_duplicate)

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
BASE_URL = 'https://www.nba.com/players'
r = requests.get(BASE_URL)
text = bs(r.text)

# %%
text
# Out:
# <!DOCTYPE html>
# ...

# %%
pd.read_html('https://www.nba.com/players')
# Out:
# [                     Player Team  Number Position Height   Weight  \
#  0           PreciousAchiuwa  MIA     NaN        F    6-9  225 lbs
#  1               StevenAdams  OKC    12.0        C   6-11  265 lbs
#  2                BamAdebayo  MIA    13.0      C-F    6-9  255 lbs
#  3          LaMarcusAldridge  SAS    12.0      C-F   6-11  250 lbs
#  4   NickeilAlexander-Walker  NOP     0.0        G    6-5  205 lbs
#  5              GraysonAllen  MEM     3.0        G    6-4  198 lbs
#  6              JarrettAllen  BKN    31.0        C   6-11  243 lbs
#  7            Al-FarouqAminu  ORL     2.0        F    6-8  220 lbs
#  8              KyleAnderson  MEM     1.0      F-G    6-9  230 lbs
#  9      GiannisAntetokounmpo  MIL    34.0        F   6-11  242 lbs
#  10    ThanasisAntetokounmpo  MIL    43.0        F    6-6  219 lbs
#  11              ColeAnthony  ORL     NaN        G    6-3  185 lbs
#  12                OGAnunoby  TOR     3.0        F    6-7  232 lbs
# ...

# %%
import pandas as pd
import datetime
import unidecode
import numpy as np
import sys

year = input("Year start? ")
x = pd.read_html('http://www.foxsports.com/nba/players?teamId=0&season=%s&position=0&playerName=&country=0&grouping=0&weightclass=0' %(year))[0]
# Out:
# Year start? 2019
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-1d9a02d19135> in <module>()
#       7
#       8 year = input("Year start? ")
# ----> 9 x = pd.read_html('http://www.foxsports.com/nba/players?teamId=0&season=%s&position=0&playerName=&country=0&grouping=0&weightclass=0' %(year))[0]
#
# /Users/Kevin/anaconda/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# /Users/Kevin/anaconda/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
# ...

# %%
for i in range(2,30):
    try:
        x = x.append(pd.read_html('http://www.foxsports.com/nba/players?teamId=0&season=%s&position=0&page=%s&country=0&grouping=0&weightclass=0' %(year,i))[0])
    except:
        print ("ends on page:", i)
        break

x.columns = ['Player','team','position','Height','Weight','Birthdate']

def splitter(x):
    return(x.split(",")[1])

x['Full_name'] = x.Player.apply(splitter)

x.index = [i for i in range(x.shape[0])]


def age(x):
    if x != "-":
        return ((datetime.datetime.today()-datetime.datetime.strptime(x,"%m/%d/%Y")).days)/365.25
    else:
        return np.nan


x['age'] = x.Birthdate.apply(age)

def splitspaceone(x):
    return x.split(" ")[1]
def splitspacetwo(x):
    return " ".join(x.split(" ")[3:])

x['First_name'] = x.Full_name.apply(splitspaceone)
x['Last_name'] = x.Full_name.apply(splitspacetwo)

def scrapedname(row):
        return (row['First_name'][0] +'. ' +row['Last_name'])



x = x.drop('Player',axis=1)

x['Name'] = x.apply(scrapedname,axis=1)


def conversion(x):
    if type(x) != int and type(x) != float and type(x)!=np.float64 and type(x) != np.int64:
        return unidecode.unidecode(x)
    else:
        return x
x = x.applymap(conversion)

x.to_csv("Player_list_%s.csv"%(year))
# Out:
# ends on page: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ae43d7de9a89> in <module>()
#       8         break
#       9
# ---> 10 x.columns = ['Player','team','position','Height','Weight','Birthdate']
#      11
#      12 def splitter(x):
#
# NameError: name 'x' is not defined

# %%
x[x.Name.duplicated(keep=False)].sort_values(by="Name").shape
# Out:
# (54, 10)

# %%
unique_players = players[~players[["Name","team","position"]].duplicated(keep = "last")]

# %%
players[~players[["Name"]].duplicated(keep = "last")].shape
# Out:
# (465, 19)

# %%
unique_players.shape
# Out:
# (488, 19)

# %%
doubles = unique_players.Name[unique_players.Name.duplicated(keep = 'first')].sort_values() #(by="Name")

# %%
x.loc[65]
# Out:
# team                     MIL
# position                   G
# Height                  6'1"
# Weight                   205
# Birthdate         12/09/1989
# Full_name      Eric  Bledsoe
# age                  28.0986
# First_name              Eric
# Last_name            Bledsoe
# Name              E. Bledsoe
# Name: 65, dtype: object

# %%
true_doubles = x[x.Name.isin(doubles)][~x.Last_name[x.Name.isin(doubles)].duplicated(keep=False)==False]

# %%
true_doubles[true_doubles[['Name','team']].duplicated()]
# Out:
# Empty DataFrame
# Columns: [team, position, Height, Weight, Birthdate, Full_name, age, First_name, Last_name, Name]
# Index: []

# %%
x[x.Name.isin(doubles)]
# Out:
#     team position Height  Weight   Birthdate            Full_name        age  \
# 48   DEN        G   6'5"     195  11/26/1996       Malik  Beasley  21.133470
# 49    NY        F   6'9"     235   1/09/1989     Michael  Beasley  29.013005
# 65   MIL        G   6'1"     205  12/09/1989        Eric  Bledsoe  28.098563
# 68   SAC       SG   6'6"     205   8/18/1992   Bogdan  Bogdanovic  25.407255
# 69   IND      G/F   6'8"     216   4/18/1989    Bojan  Bogdanovic  28.741958
# 74   PHI      F/C   6'8"     228  11/25/1987       Trevor  Booker  30.138261
# 102  PHX       PG   6'0"     201   5/21/1991       Isaiah  Canaan  26.652977
# 140  MIN      G/F   6'5"     185   3/20/1980      Jamal  Crawford  37.820671
# 141   NO        G   6'4"     195  10/23/1988     Jordan  Crawford  29.226557
# 220  OKC        F   6'9"     220   3/12/1994        Jerami  Grant  23.843943
# 221  CHI        G   6'4"     205  10/09/1992        Jerian  Grant  25.264887
# ...

# %%
merger = x.merge(players,how="left",on= "Name")

# %%
merger.head()
# Out:
#   team_x position_x Height  Weight  Birthdate       Full_name        age  \
# 0    OKC         SG   6'6"     190  8/01/1993   Alex  Abrines  24.454483
# 1    OKC         SG   6'6"     190  8/01/1993   Alex  Abrines  24.454483
# 2    OKC         SG   6'6"     190  8/01/1993   Alex  Abrines  24.454483
# 3    OKC         SG   6'6"     190  8/01/1993   Alex  Abrines  24.454483
# 4    OKC         SG   6'6"     190  8/01/1993   Alex  Abrines  24.454483
#
#   First_name Last_name        Name    ...      DREB REB AST STL BLK TO PF  \
# 0       Alex   Abrines  A. Abrines    ...         3   3   0   1   0  2  3
# 1       Alex   Abrines  A. Abrines    ...         0   0   0   1   0  0  4
# 2       Alex   Abrines  A. Abrines    ...         1   2   1   1   0  0  3
# 3       Alex   Abrines  A. Abrines    ...         0   0   0   0   0  0  3
# 4       Alex   Abrines  A. Abrines    ...         2   2   1   2   0  1  2
#
#    +/- PTS position_y
# 0  +23   3         SG
# 1  +13   4         SG
# ...

# %% [markdown]
# # Trying to come up with a way of tracking trades

# %%
trades = pd.read_html("https://en.wikipedia.org/wiki/List_of_2017%E2%80%9318_NBA_season_transactions")[3]

# %%
import datetime

# %%
def date_it(x):
    try:
        return datetime.datetime.strptime(x,'%B %d').replace(year=2017)
    except:
        return datetime.datetime(1900,1,1)

# %%
date_it("June 19")
# Out:
# datetime.datetime(2017, 6, 19, 0, 0)

# %%
date_it(trades[0][0])
# Out:
# datetime.datetime(1900, 1, 1, 0, 0)

# %%
trades.head()
# Out:
#                             0  \
# 0                        June
# 1                     June 19
# 2                     June 20
# 3                     June 21
# 4  June 22 (Draft-day trades)
#
#                                                    1  \
# 0                                                NaN
# 1  To Philadelphia 76ers 2017 Brooklyn first-roun...
# 2  To Charlotte Hornets Dwight Howard 2017 Brookl...
# 3  To New Orleans Pelicans 2017 Washington second...
# 4   To Brooklyn Nets D'Angelo Russell Timofey Mozgov
#
#                                                    2     3       Date
# 0                                                NaN   NaN 1900-01-01
# 1  To Boston Celtics 2017 Sacramento first-round ...  [31] 1900-06-19
# 2  To Atlanta Hawks Miles Plumlee Marco Belinelli...  [32] 1900-06-20
# 3                  To Washington Wizards Tim Frazier  [33] 1900-06-21
# 4  To Los Angeles Lakers Brook Lopez Draft rights...  [34] 1900-01-01

# %%
trades["Date"] = trades[0].apply(date_it)

# %%
trades[trades.Date>datetime.datetime(2017,10,15)]
# Out:
#              0                                    1  \
# 47  November 7      To Milwaukee Bucks Eric Bledsoe
# 49  December 7  To Philadelphia 76ers Trevor Booker
#
#                                                     2         3       Date
# 47  To Phoenix Suns Greg Monroe 2018 protected fir...  [70][71] 2017-11-07
# 49  To Brooklyn Nets Jahlil Okafor Nik Stauskas 20...      [72] 2017-12-07

# %%
[i for i in trades[1][trades.Date>datetime.datetime(2017,10,15)]]
# Out:
# ['To Milwaukee Bucks Eric Bledsoe', 'To Philadelphia 76ers Trevor Booker']

# %%
traded = []

for i in doubles.apply(lambda x: x.split()[1]):
    for j in trades[1][trades.Date>datetime.datetime(1900,10,15)]:
        for k in trades[2][trades.Date>datetime.datetime(1900,10,15)]:
            if i in j or i in k:
                if i not in traded:
                    traded.append(i)
                    
print(traded)
# Out:
# ['Bledsoe', 'Monroe', 'Okafor', 'Plumlee', 'Stauskas', 'Booker']

# %%
x[(x.Name.isin(doubles)) & (x.Last_name.isin(traded))]
# Out:
#     team position Height  Weight   Birthdate        Full_name        age  \
# 65   MIL        G   6'1"     205  12/09/1989    Eric  Bledsoe  28.098563
# 74   PHI      F/C   6'8"     228  11/25/1987   Trevor  Booker  30.138261
# 419  PHX      F/C  6'11"     265   6/04/1990     Greg  Monroe  27.613963
# 463  BKN        C  6'11"     255  12/15/1995   Jahlil  Okafor  22.083504
# 564  BKN      G/F   6'6"     205  10/07/1993    Nik  Stauskas  24.271047
#
#     First_name Last_name         Name
# 65        Eric   Bledsoe   E. Bledsoe
# 74      Trevor    Booker    T. Booker
# 419       Greg    Monroe    G. Monroe
# 463     Jahlil    Okafor    J. Okafor
# 564        Nik  Stauskas  N. Stauskas
